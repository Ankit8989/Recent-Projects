# %%
import pandas as pd
import numpy as np

# %%
url='https://raw.githubusercontent.com/skathirmani/datasets/main/naukri_jobs_datascience.csv'
jobs=pd.read_csv(url)
jobs.shape
# Out:
# (4000, 11)

# %%
jobs.head(5)
# Out:
#              id                                      title  \
# 0  280918001664                               Data Science
# 1  280818003404       Analyst / Sr. Analyst (data Science)
# 2  280918008755                    ETL Lead & Data Science
# 3  270918901342                  Specialist - Data Science
# 4  260918002450  Group Manager - Data Science - Python/nlp
#
#                                   location experience  \
# 0                                   Mumbai    2-4 yrs
# 1                                  Gurgaon    5-8 yrs
# 2  Chennai, Bengaluru, Mumbai, Pune, Noida   7-10 yrs
# 3            Delhi NCR, Bengaluru, Gurgaon   7-12 yrs
# 4                                Bengaluru   6-11 yrs
#
#                                               skills  \
# 0  Algorithms, Machine Learning, Python, Java, Da...
# 1  predictive modeling, predictive analytics, mac...
# 2  SQL, Data Analysis, Text Mining, SAS, R, Stati...
# 3  Specialist - Data Science, Data Science, data ...
# ...

# %%
# Exercises

# Extract minimum years of experince required for each job and store in new column min_experience
# Identify for each job,count the number of location

# %%
jobs['min_experience']=jobs['experience'].dropna().apply(lambda v:v.split(' ')[0].split('-')[0])
#jobs['max_experience']=jobs['experience'].dropna().apply(lambda v: v.split('')[0].split('-')[1])

# %%
jobs['experience'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3995    False
# 3996    False
# 3997    False
# 3998    False
# 3999    False
# Name: experience, Length: 4000, dtype: bool

# %%
jobs['no_of_location']=jobs['location'].apply(lambda v:len(v.split(',')))   
jobs['no_of_location'].value_counts().sort_index()
# Out:
# 1    3601
# 2     275
# 3     102
# 4      10
# 5       6
# 6       5
# 9       1
# Name: no_of_location, dtype: int64

# %%
jobs['salary'].unique()
# Out:
# array(['    2,00,000 - 7,00,000 P.A.  ',
#        '    5,00,000 - 10,00,000 P.A.  ',
#        '    10,00,000 - 15,00,000 P.A.  ', '  Not disclosed ',
#        '    2,00,000 - 4,25,000 P.A.  ', '    4,00,000 - 8,00,000 P.A.  ',
#        '    1,00,000 - 3,00,000 P.A.  ', '    1,25,000 - 3,00,000 P.A.  ',
#        '    1,25,000 - 4,00,000 P.A. Best salary as per Industry & ...  ',
#        '    2,50,000 - 7,50,000 P.A.  ', '    4,00,000 - 7,50,000 P.A.  ',
#        '    22,50,000 - 35,00,000 P.A.  ',
#        '    12,00,000 - 18,00,000 P.A.  ',
#        '    13,00,000 - 20,00,000 P.A.  ',
#        '    3,00,000 - 8,00,000 P.A. 40%  ',
#        '    8,00,000 - 10,00,000 P.A.  ',
#        '    1,00,000 - 4,00,000 P.A.  ', '    50,000 - 2,00,000 P.A.  ',
#        '    7,00,000 - 17,00,000 P.A.  ',
#        '    6,00,000 - 12,00,000 P.A.  ',
#        '    10,00,000 - 20,00,000 P.A.  ', '    Rs. 1.50 Lac/month  ',
#        '    PB-3 Rs15600-39100 with minimum pay of Rs30000 + AGP of...  ',
# ...

# %% [markdown]
# # Work with Text Column

# %%
jobs['no_of_location']=jobs['location'].str.split(',').str.len()

# %%
jobs['no_of_location']
# Out:
# 0       1
# 1       1
# 2       5
# 3       3
# 4       1
#        ..
# 3995    2
# 3996    1
# 3997    1
# 3998    1
# 3999    1
# Name: no_of_location, Length: 4000, dtype: int64

# %%
jobs['experience'].str.split('').str[0].str.split('-').str[0].str.split('-').str[0]
# Out:
# 0
# 1
# 2
# 3
# 4
#        ..
# 3995
# 3996
# 3997
# 3998
# 3999
# Name: experience, Length: 4000, dtype: object

# %%
import re 

exp=jobs.iloc[0]['experience']
print(exp)

print(re.findall('[0-9,a-z,A-Z\s]+','1234-5678'))
# Out:
# 2-4 yrs
# ['1234', '5678']

# %%
pattern='[0-9]+-([0-9]+)'
exps=jobs['experience'].head(5).tolist()
[re.findall(pattern,i) for i in exps]
# Out:
# [['4'], ['8'], ['10'], ['12'], ['11']]

# %%
pattern='[0-9]+-([0-9]+)'
